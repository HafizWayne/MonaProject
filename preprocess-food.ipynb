# %%
# !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
# done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /opt/conda/lib/python3.10/site-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.2.2)
# Building wheels for collected packages: googlemaps
# done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40711 sha256=0424b071df6c2c124726d8c7317922096769ddf75fd61fb378ff99a742469b83
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
import requests
import numpy as np 
import pandas as pd
import os
import googlemaps
from datetime import datetime
import urllib.parse

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/indonesia-food-delivery-gofood-product-list/gofood_dataset.csv

# %% [markdown]
# # Gathering Data

# %%
df = pd.read_csv("/kaggle/input/indonesia-food-delivery-gofood-product-list/gofood_dataset.csv", delimiter=",")

# %%
df.head()
# Out:
#        merchant_name merchant_area           category    display  \
# 0  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 1  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 2  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 3  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 4  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
#
#                                  product    price  discount_price  isDiscount  \
# 0  Hot Almara Kopi (kopi Susu Gula Aren)  20000.0             NaN           0
# 1  Ice Almara Kopi (kopi Susu Gula Aren)  22000.0             NaN           0
# 2                            Hot Millsis  20000.0             NaN           0
# 3                            Ice Millsis  20000.0             NaN           0
# 4                            Hot Millbro  22000.0             NaN           0
#
#                                          description
# 0  Sajian Kopi Susu Gula Aren Yang Berbeda Dari K...
# 1  Sajian Kopi Susu Gula Aren Yang Berbeda Dari K...
# 2  Sajian Susu Coklat Milo Dengan Racikan Khas 3 ...
# 3  Sajian Susu Coklat Milo Dengan Racikan Khas 3 ...
# 4  Sajian Susu Coklat Milo Plus Espresso Dengan R...

# %% [markdown]
# # Acessing Data

# %%
df.isnull().sum()
# Out:
# merchant_name         0
# merchant_area         0
# category              0
# display               0
# product               0
# price                 0
# discount_price    42457
# isDiscount            0
# description       23475
# dtype: int64

# %% [markdown]
# Masih nyatu untuk 1 nama merchant

# %%
df.duplicated().sum()
# Out:
# 5547

# %% [markdown]
# # 1. Penyatuan Satu Merchant dan Rata Rata Harga 1 Merchant

# %% [markdown]
# ### Filter Hanya Jakarta

# %%
df_jakarta = df[df['merchant_area'] == 'jakarta']
df_jakarta.head()
# Out:
#        merchant_name merchant_area           category    display  \
# 0  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 1  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 2  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 3  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
# 4  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  Signature
#
#                                  product    price  discount_price  isDiscount  \
# 0  Hot Almara Kopi (kopi Susu Gula Aren)  20000.0             NaN           0
# 1  Ice Almara Kopi (kopi Susu Gula Aren)  22000.0             NaN           0
# 2                            Hot Millsis  20000.0             NaN           0
# 3                            Ice Millsis  20000.0             NaN           0
# 4                            Hot Millbro  22000.0             NaN           0
#
#                                          description
# 0  Sajian Kopi Susu Gula Aren Yang Berbeda Dari K...
# 1  Sajian Kopi Susu Gula Aren Yang Berbeda Dari K...
# 2  Sajian Susu Coklat Milo Dengan Racikan Khas 3 ...
# 3  Sajian Susu Coklat Milo Dengan Racikan Khas 3 ...
# 4  Sajian Susu Coklat Milo Plus Espresso Dengan R...

# %%
df_jakarta = df_jakarta.drop(['display', 'product', 'discount_price', 'isDiscount', 'description'], axis="columns")
df_jakarta.head()
# Out:
#        merchant_name merchant_area           category    price
# 0  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  20000.0
# 1  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  22000.0
# 2  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  20000.0
# 3  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  20000.0
# 4  330 Kopi, Ciledug       jakarta  Kopi/Minuman/Roti  22000.0

# %% [markdown]
# ### Quartil dan Jumlah Quartil

# %%
grouped = df_jakarta.groupby(['merchant_name', 'merchant_area', 'category'])['price'].apply(list).reset_index()
grouped.head()
# Out:
#            merchant_name merchant_area                  category  \
# 0      330 Kopi, Ciledug       jakarta         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur       jakarta  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang       jakarta                     Barat
# 3   Aneka Gorengan Siaga       jakarta           Jajanan/Minuman
# 4            Arangsimpur       jakarta                   Chinese
#
#                                                price
# 0  [20000.0, 22000.0, 20000.0, 20000.0, 22000.0, ...
# 1  [70000.0, 33000.0, 105000.0, 100000.0, 90000.0...
# 2  [13200.0, 35200.0, 35200.0, 49500.0, 39600.0, ...
# 3  [1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500....
# 4  [34000.0, 39000.0, 48000.0, 48000.0, 6000.0, 2...

# %%
def calculate_quartiles(row):
    values = sorted(row['price'])
    q1 = pd.Series(values).quantile(0.25)
    q2 = pd.Series(values).quantile(0.50)
    q3 = pd.Series(values).quantile(0.75)
    
    q1_count = sum(1 for v in values if v <= q1)
    q2_count = sum(1 for v in values if q1 < v <= q2)
    q3_count = sum(1 for v in values if q2 < v <= q3)
    q4_count = sum(1 for v in values if v > q3)
    
    return pd.Series({
        'Q1': q1,
        'Q2': q2,
        'Q3': q3,
        'Q1_count': q1_count,
        'Q2_count': q2_count,
        'Q3_count': q3_count,
        'Q4_count': q4_count
    })

# Apply the function to each row in the grouped dataframe
quartiles = grouped.apply(calculate_quartiles, axis=1)

# Combine the results with the grouped dataframe
result = pd.concat([grouped, quartiles], axis=1)

# %%
# df_jakarta_quartilize = result.drop('price', axis='columns')
df_jakarta_quartilize = result
df_jakarta_quartilize.head()
# Out:
#            merchant_name merchant_area                  category  \
# 0      330 Kopi, Ciledug       jakarta         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur       jakarta  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang       jakarta                     Barat
# 3   Aneka Gorengan Siaga       jakarta           Jajanan/Minuman
# 4            Arangsimpur       jakarta                   Chinese
#
#                                                price       Q1       Q2  \
# 0  [20000.0, 22000.0, 20000.0, 20000.0, 22000.0, ...  20000.0  22000.0
# 1  [70000.0, 33000.0, 105000.0, 100000.0, 90000.0...  18000.0  25000.0
# 2  [13200.0, 35200.0, 35200.0, 49500.0, 39600.0, ...  28600.0  44000.0
# 3  [1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500....   1500.0   5000.0
# 4  [34000.0, 39000.0, 48000.0, 48000.0, 6000.0, 2...  30250.0  36500.0
#
#         Q3  Q1_count  Q2_count  Q3_count  Q4_count
# 0  25000.0      26.0      13.0      10.0      15.0
# 1  33000.0      17.0      14.0      10.0      13.0
# 2  82500.0      29.0      21.0      24.0      25.0
# 3   5000.0      12.0      16.0       0.0       8.0
# 4  45750.0       2.0       1.0       1.0       2.0

# %% [markdown]
# ### Kategori Harga

# %% [markdown]
# Katgeori harga berdasarkan quartil terbanyak

# %%
df_jakarta_quartilize['target_price'] = df_jakarta_quartilize[['Q1_count', 'Q2_count', 'Q3_count', 'Q4_count']].idxmax(axis=1)
df_jakarta_quartilize['target_price'] = df_jakarta_quartilize['target_price'].str.replace('_count', '')
df_jakarta_quartilize.head()
# Out:
#            merchant_name merchant_area                  category  \
# 0      330 Kopi, Ciledug       jakarta         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur       jakarta  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang       jakarta                     Barat
# 3   Aneka Gorengan Siaga       jakarta           Jajanan/Minuman
# 4            Arangsimpur       jakarta                   Chinese
#
#                                                price       Q1       Q2  \
# 0  [20000.0, 22000.0, 20000.0, 20000.0, 22000.0, ...  20000.0  22000.0
# 1  [70000.0, 33000.0, 105000.0, 100000.0, 90000.0...  18000.0  25000.0
# 2  [13200.0, 35200.0, 35200.0, 49500.0, 39600.0, ...  28600.0  44000.0
# 3  [1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500....   1500.0   5000.0
# 4  [34000.0, 39000.0, 48000.0, 48000.0, 6000.0, 2...  30250.0  36500.0
#
#         Q3  Q1_count  Q2_count  Q3_count  Q4_count target_price
# 0  25000.0      26.0      13.0      10.0      15.0           Q1
# 1  33000.0      17.0      14.0      10.0      13.0           Q1
# 2  82500.0      29.0      21.0      24.0      25.0           Q1
# 3   5000.0      12.0      16.0       0.0       8.0           Q2
# 4  45750.0       2.0       1.0       1.0       2.0           Q1

# %%
def calculate_most(row):
    if row['Q1_count'] >= row['Q2_count'] and row['Q1_count'] >= row['Q3_count']:
        return row['Q1']/1000
    elif row['Q2_count'] >= row['Q1_count'] and row['Q2_count'] >= row['Q3_count']:
        return row['Q2']/1000
    else:
        return row['Q3']/1000

df_jakarta_quartilize['target_price'] = df_jakarta_quartilize.apply(calculate_most, axis=1)
df_jakarta_quartilize.head()
# Out:
#            merchant_name merchant_area                  category  \
# 0      330 Kopi, Ciledug       jakarta         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur       jakarta  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang       jakarta                     Barat
# 3   Aneka Gorengan Siaga       jakarta           Jajanan/Minuman
# 4            Arangsimpur       jakarta                   Chinese
#
#                                                price       Q1       Q2  \
# 0  [20000.0, 22000.0, 20000.0, 20000.0, 22000.0, ...  20000.0  22000.0
# 1  [70000.0, 33000.0, 105000.0, 100000.0, 90000.0...  18000.0  25000.0
# 2  [13200.0, 35200.0, 35200.0, 49500.0, 39600.0, ...  28600.0  44000.0
# 3  [1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500....   1500.0   5000.0
# 4  [34000.0, 39000.0, 48000.0, 48000.0, 6000.0, 2...  30250.0  36500.0
#
#         Q3  Q1_count  Q2_count  Q3_count  Q4_count  target_price
# 0  25000.0      26.0      13.0      10.0      15.0         20.00
# 1  33000.0      17.0      14.0      10.0      13.0         18.00
# 2  82500.0      29.0      21.0      24.0      25.0         28.60
# 3   5000.0      12.0      16.0       0.0       8.0          5.00
# 4  45750.0       2.0       1.0       1.0       2.0         30.25

# %%
def categorize_price(most):
    if 0 <= most <= 18:
        return '1'
    elif 18000 < most <= 30:
        return '2'
    elif most > 30:
        return '3'
    else:
        return '0'  

df_jakarta_quartilize['price_category'] = df_jakarta_quartilize['target_price'].apply(categorize_price)
df_jakarta_quartilize.head()
# Out:
#            merchant_name merchant_area                  category  \
# 0      330 Kopi, Ciledug       jakarta         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur       jakarta  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang       jakarta                     Barat
# 3   Aneka Gorengan Siaga       jakarta           Jajanan/Minuman
# 4            Arangsimpur       jakarta                   Chinese
#
#                                                price       Q1       Q2  \
# 0  [20000.0, 22000.0, 20000.0, 20000.0, 22000.0, ...  20000.0  22000.0
# 1  [70000.0, 33000.0, 105000.0, 100000.0, 90000.0...  18000.0  25000.0
# 2  [13200.0, 35200.0, 35200.0, 49500.0, 39600.0, ...  28600.0  44000.0
# 3  [1500.0, 1500.0, 1500.0, 1500.0, 1500.0, 1500....   1500.0   5000.0
# 4  [34000.0, 39000.0, 48000.0, 48000.0, 6000.0, 2...  30250.0  36500.0
#
#         Q3  Q1_count  Q2_count  Q3_count  Q4_count  target_price  \
# 0  25000.0      26.0      13.0      10.0      15.0         20.00
# 1  33000.0      17.0      14.0      10.0      13.0         18.00
# 2  82500.0      29.0      21.0      24.0      25.0         28.60
# 3   5000.0      12.0      16.0       0.0       8.0          5.00
# 4  45750.0       2.0       1.0       1.0       2.0         30.25
#
#   price_category
# 0              0
# 1              1
# 2              0
# 3              1
# 4              3

# %% [markdown]
# ### Price Min and Max

# %% [markdown]
# Normalisasi dengan dibagi 1000

# %%
df_jakarta_quartilize['price'] = df_jakarta_quartilize['price'].apply(lambda x: [i / 1000 for i in x])
df_jakarta_quartilize['price_min'] = df_jakarta_quartilize['price'].apply(lambda x: min(x))
df_jakarta_quartilize['price_max'] = df_jakarta_quartilize['price'].apply(lambda x: max(x))
df_jakarta_quartilize.head()
# Out:
#            merchant_name merchant_area                  category  \
# 0      330 Kopi, Ciledug       jakarta         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur       jakarta  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang       jakarta                     Barat
# 3   Aneka Gorengan Siaga       jakarta           Jajanan/Minuman
# 4            Arangsimpur       jakarta                   Chinese
#
#                                                price       Q1       Q2  \
# 0  [20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 15.0, 18....  20000.0  22000.0
# 1  [70.0, 33.0, 105.0, 100.0, 90.0, 165.0, 20.0, ...  18000.0  25000.0
# 2  [13.2, 35.2, 35.2, 49.5, 39.6, 44.0, 28.6, 28....  28600.0  44000.0
# 3  [1.5, 1.5, 1.5, 1.5, 1.5, 1.5, 2.0, 1.5, 1.5, ...   1500.0   5000.0
# 4                [34.0, 39.0, 48.0, 48.0, 6.0, 29.0]  30250.0  36500.0
#
#         Q3  Q1_count  Q2_count  Q3_count  Q4_count  target_price  \
# 0  25000.0      26.0      13.0      10.0      15.0         20.00
# 1  33000.0      17.0      14.0      10.0      13.0         18.00
# 2  82500.0      29.0      21.0      24.0      25.0         28.60
# 3   5000.0      12.0      16.0       0.0       8.0          5.00
# 4  45750.0       2.0       1.0       1.0       2.0         30.25
#
#   price_category  price_min  price_max
# 0              0       15.0       37.0
# 1              1        5.0      165.0
# 2              0       13.2      352.0
# 3              1        1.5       20.0
# 4              3        6.0       48.0

# %% [markdown]
# ### Celaning data tidak diperlukan

# %%
df_jakarta_quartilize = df_jakarta_quartilize.drop(['Q1', 'Q2', 'Q3', 'Q1_count', 'Q2_count', 'Q3_count', 'Q4_count'], axis="columns")
df_jakarta_quartilize.head()
# Out:
#            merchant_name merchant_area                  category  \
# 0      330 Kopi, Ciledug       jakarta         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur       jakarta  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang       jakarta                     Barat
# 3   Aneka Gorengan Siaga       jakarta           Jajanan/Minuman
# 4            Arangsimpur       jakarta                   Chinese
#
#                                                price  target_price  \
# 0  [20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 15.0, 18....         20.00
# 1  [70.0, 33.0, 105.0, 100.0, 90.0, 165.0, 20.0, ...         18.00
# 2  [13.2, 35.2, 35.2, 49.5, 39.6, 44.0, 28.6, 28....         28.60
# 3  [1.5, 1.5, 1.5, 1.5, 1.5, 1.5, 2.0, 1.5, 1.5, ...          5.00
# 4                [34.0, 39.0, 48.0, 48.0, 6.0, 29.0]         30.25
#
#   price_category  price_min  price_max
# 0              0       15.0       37.0
# 1              1        5.0      165.0
# 2              0       13.2      352.0
# 3              1        1.5       20.0
# 4              3        6.0       48.0

# %% [markdown]
# # 2. Penambahan Koordinat

# %% [markdown]
# ### Penggabungan Merchant Name dan Merchant Area

# %%
def combine_columns(row):
    merchant_name = row['merchant_name']
    merchant_area = row['merchant_area'].capitalize()
    return f"{merchant_name}, {merchant_area}"
df_jakarta_coor = df_jakarta_quartilize
df_jakarta_coor['alamat'] = df_jakarta_coor.apply(combine_columns, axis=1)
df_jakarta_coor.head()
# Out:
#            merchant_name merchant_area                  category  \
# 0      330 Kopi, Ciledug       jakarta         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur       jakarta  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang       jakarta                     Barat
# 3   Aneka Gorengan Siaga       jakarta           Jajanan/Minuman
# 4            Arangsimpur       jakarta                   Chinese
#
#                                                price  target_price  \
# 0  [20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 15.0, 18....         20.00
# 1  [70.0, 33.0, 105.0, 100.0, 90.0, 165.0, 20.0, ...         18.00
# 2  [13.2, 35.2, 35.2, 49.5, 39.6, 44.0, 28.6, 28....         28.60
# 3  [1.5, 1.5, 1.5, 1.5, 1.5, 1.5, 2.0, 1.5, 1.5, ...          5.00
# 4                [34.0, 39.0, 48.0, 48.0, 6.0, 29.0]         30.25
#
#   price_category  price_min  price_max                          alamat
# 0              0       15.0       37.0      330 Kopi, Ciledug, Jakarta
# 1              1        5.0      165.0     Abe Steak, Cibubur, Jakarta
# 2              0       13.2      352.0  Abuba Steak, Cikarang, Jakarta
# 3              1        1.5       20.0   Aneka Gorengan Siaga, Jakarta
# 4              3        6.0       48.0            Arangsimpur, Jakarta

# %% [markdown]
# ### Penambahan Coordinate dengan Google Maps

# %%
# Masukkan API OpenCage kalian di sini (Google Cloud Google Maps API for JS)
gmaps = googlemaps.Client(key='AIzaSyDSCnOXFsAjV7v-JuC5c2IGbU9ZXuJpn1A')

# %%
def search_place(place_name):
    # Melakukan permintaan ke Google Maps API
    geocode_result = gmaps.geocode(place_name)

    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        lat = location['lat']
        lng = location['lng']
        address = geocode_result[0]['formatted_address']
        encoded_place_name = urllib.parse.quote(place_name)
        link = f"https://www.google.com/maps/search/?api=1&query={encoded_place_name}"
        return lat, lng, link
    else:
        print("Lokasi tidak ditemukan.")
        return None, None

df_jakarta_coor['lat'], df_jakarta_coor['lng'], df_jakarta_coor['link'] = zip(*df_jakarta_coor['alamat'].apply(lambda x: search_place(x)))

# %%
df_jakarta_coor.head(10)
# Out:
#            merchant_name merchant_area                         category  \
# 0      330 Kopi, Ciledug       jakarta                Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur       jakarta         Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang       jakarta                            Barat
# 3   Aneka Gorengan Siaga       jakarta                  Jajanan/Minuman
# 4            Arangsimpur       jakarta                          Chinese
# 5            Ayam Trolok       jakarta  Aneka nasi/Ayam & bebek/Seafood
# 6   BABAKARAN BUNDA DAFA       jakarta         Minuman/Jajanan/Martabak
# 7         Bakerman, SCBD       jakarta             Roti/Minuman/Jajanan
# 8              Bakmi Kun       jakarta   Ayam & bebek/Bakmie/Cepat saji
# 9         Bakmi Lopui 93       jakarta           Bakmie/Chinese/Minuman
#
#                                                price  target_price  \
# 0  [20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 15.0, 18....         20.00
# 1  [70.0, 33.0, 105.0, 100.0, 90.0, 165.0, 20.0, ...         18.00
# 2  [13.2, 35.2, 35.2, 49.5, 39.6, 44.0, 28.6, 28....         28.60
# 3  [1.5, 1.5, 1.5, 1.5, 1.5, 1.5, 2.0, 1.5, 1.5, ...          5.00
# 4                [34.0, 39.0, 48.0, 48.0, 6.0, 29.0]         30.25
# 5  [100.0, 6.0, 25.0, 25.0, 6.0, 6.0, 6.0, 7.5, 1...          6.00
# 6  [6.0, 20.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0...         15.00
# 7  [626.2, 246.7, 35.4, 48.1, 48.1, 82.225, 50.6,...         69.60
# 8  [49.0, 42.0, 42.0, 42.0, 42.0, 35.0, 65.0, 65....         27.50
# 9  [25.0, 30.0, 25.0, 30.0, 30.0, 25.0, 30.0, 30....         30.00
#
#   price_category  price_min  price_max                          alamat  \
# 0              0       15.0       37.0      330 Kopi, Ciledug, Jakarta
# 1              1        5.0      165.0     Abe Steak, Cibubur, Jakarta
# 2              0       13.2      352.0  Abuba Steak, Cikarang, Jakarta
# 3              1        1.5       20.0   Aneka Gorengan Siaga, Jakarta
# 4              3        6.0       48.0            Arangsimpur, Jakarta
# 5              1        4.0      100.0            Ayam Trolok, Jakarta
# 6              1        6.0       25.0   BABAKARAN BUNDA DAFA, Jakarta
# 7              3       12.7      626.2         Bakerman, SCBD, Jakarta
# 8              0        8.0      300.0              Bakmi Kun, Jakarta
# 9              0       15.0       30.0         Bakmi Lopui 93, Jakarta
#
#         lat         lng                                               link
# 0 -6.238135  106.716900  https://www.google.com/maps/search/?api=1&quer...
# 1 -6.356087  106.879792  https://www.google.com/maps/search/?api=1&quer...
# 2 -6.194449  106.822920  https://www.google.com/maps/search/?api=1&quer...
# 3 -6.274045  106.839772  https://www.google.com/maps/search/?api=1&quer...
# 4 -6.240159  106.651125  https://www.google.com/maps/search/?api=1&quer...
# 5 -6.194449  106.822920  https://www.google.com/maps/search/?api=1&quer...
# 6 -6.140373  106.832440  https://www.google.com/maps/search/?api=1&quer...
# 7 -6.228628  106.806919  https://www.google.com/maps/search/?api=1&quer...
# 8 -6.270742  106.812494  https://www.google.com/maps/search/?api=1&quer...
# 9 -6.152886  106.813341  https://www.google.com/maps/search/?api=1&quer...

# %%
df_jakarta_coor = df_jakarta_coor.drop(['merchant_area'], axis="columns")
df_jakarta_coor.head()
# Out:
#            merchant_name                  category  \
# 0      330 Kopi, Ciledug         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang                     Barat
# 3   Aneka Gorengan Siaga           Jajanan/Minuman
# 4            Arangsimpur                   Chinese
#
#                                                price  target_price  \
# 0  [20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 15.0, 18....         20.00
# 1  [70.0, 33.0, 105.0, 100.0, 90.0, 165.0, 20.0, ...         18.00
# 2  [13.2, 35.2, 35.2, 49.5, 39.6, 44.0, 28.6, 28....         28.60
# 3  [1.5, 1.5, 1.5, 1.5, 1.5, 1.5, 2.0, 1.5, 1.5, ...          5.00
# 4                [34.0, 39.0, 48.0, 48.0, 6.0, 29.0]         30.25
#
#   price_category  price_min  price_max                          alamat  \
# 0              0       15.0       37.0      330 Kopi, Ciledug, Jakarta
# 1              1        5.0      165.0     Abe Steak, Cibubur, Jakarta
# 2              0       13.2      352.0  Abuba Steak, Cikarang, Jakarta
# 3              1        1.5       20.0   Aneka Gorengan Siaga, Jakarta
# 4              3        6.0       48.0            Arangsimpur, Jakarta
#
#         lat         lng                                               link
# 0 -6.238135  106.716900  https://www.google.com/maps/search/?api=1&quer...
# 1 -6.356087  106.879792  https://www.google.com/maps/search/?api=1&quer...
# 2 -6.194449  106.822920  https://www.google.com/maps/search/?api=1&quer...
# 3 -6.274045  106.839772  https://www.google.com/maps/search/?api=1&quer...
# 4 -6.240159  106.651125  https://www.google.com/maps/search/?api=1&quer...

# %% [markdown]
# ### Kategori makanan menjadi kode kategori

# %%
df_temp = None
df_temp = df_jakarta_coor
df_temp.head()
# Out:
#            merchant_name                  category  \
# 0      330 Kopi, Ciledug         Kopi/Minuman/Roti
# 1     Abe Steak, Cibubur  Aneka nasi/Minuman/Barat
# 2  Abuba Steak, Cikarang                     Barat
# 3   Aneka Gorengan Siaga           Jajanan/Minuman
# 4            Arangsimpur                   Chinese
#
#                                                price  target_price  \
# 0  [20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 15.0, 18....         20.00
# 1  [70.0, 33.0, 105.0, 100.0, 90.0, 165.0, 20.0, ...         18.00
# 2  [13.2, 35.2, 35.2, 49.5, 39.6, 44.0, 28.6, 28....         28.60
# 3  [1.5, 1.5, 1.5, 1.5, 1.5, 1.5, 2.0, 1.5, 1.5, ...          5.00
# 4                [34.0, 39.0, 48.0, 48.0, 6.0, 29.0]         30.25
#
#   price_category  price_min  price_max                          alamat  \
# 0              0       15.0       37.0      330 Kopi, Ciledug, Jakarta
# 1              1        5.0      165.0     Abe Steak, Cibubur, Jakarta
# 2              0       13.2      352.0  Abuba Steak, Cikarang, Jakarta
# 3              1        1.5       20.0   Aneka Gorengan Siaga, Jakarta
# 4              3        6.0       48.0            Arangsimpur, Jakarta
#
#         lat         lng                                               link
# 0 -6.238135  106.716900  https://www.google.com/maps/search/?api=1&quer...
# 1 -6.356087  106.879792  https://www.google.com/maps/search/?api=1&quer...
# 2 -6.194449  106.822920  https://www.google.com/maps/search/?api=1&quer...
# 3 -6.274045  106.839772  https://www.google.com/maps/search/?api=1&quer...
# 4 -6.240159  106.651125  https://www.google.com/maps/search/?api=1&quer...

# %%
all_cat = sum(df_temp['category'].str.split('/').tolist(), [])
unique_cat = sorted(set(all_cat))
cat_to_code = {cat: code for code, cat in enumerate(unique_cat, 1)}
def split_and_encode(cat):
    cat_list = cat.split('/')
    encoded_list = [cat_to_code[cat] for cat in cat_list]
    return encoded_list
df_temp['category'] = df_temp['category'].apply(split_and_encode)
df_temp.head()
# Out:
#            merchant_name      category  \
# 0      330 Kopi, Ciledug  [11, 14, 16]
# 1     Abe Steak, Cibubur    [1, 14, 5]
# 2  Abuba Steak, Cikarang           [5]
# 3   Aneka Gorengan Siaga       [9, 14]
# 4            Arangsimpur           [7]
#
#                                                price  target_price  \
# 0  [20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 15.0, 18....         20.00
# 1  [70.0, 33.0, 105.0, 100.0, 90.0, 165.0, 20.0, ...         18.00
# 2  [13.2, 35.2, 35.2, 49.5, 39.6, 44.0, 28.6, 28....         28.60
# 3  [1.5, 1.5, 1.5, 1.5, 1.5, 1.5, 2.0, 1.5, 1.5, ...          5.00
# 4                [34.0, 39.0, 48.0, 48.0, 6.0, 29.0]         30.25
#
#   price_category  price_min  price_max                          alamat  \
# 0              0       15.0       37.0      330 Kopi, Ciledug, Jakarta
# 1              1        5.0      165.0     Abe Steak, Cibubur, Jakarta
# 2              0       13.2      352.0  Abuba Steak, Cikarang, Jakarta
# 3              1        1.5       20.0   Aneka Gorengan Siaga, Jakarta
# 4              3        6.0       48.0            Arangsimpur, Jakarta
#
#         lat         lng                                               link
# 0 -6.238135  106.716900  https://www.google.com/maps/search/?api=1&quer...
# 1 -6.356087  106.879792  https://www.google.com/maps/search/?api=1&quer...
# 2 -6.194449  106.822920  https://www.google.com/maps/search/?api=1&quer...
# 3 -6.274045  106.839772  https://www.google.com/maps/search/?api=1&quer...
# 4 -6.240159  106.651125  https://www.google.com/maps/search/?api=1&quer...

# %%
print(f"Unique categories: {cat_to_code}")
# Out:
# Unique categories: {'Aneka nasi': 1, 'Ayam & bebek': 2, 'Bakmie': 3, 'Bakso & soto': 4, 'Barat': 5, 'Cepat saji': 6, 'Chinese': 7, 'India': 8, 'Jajanan': 9, 'Jepang': 10, 'Kopi': 11, 'Korea': 12, 'Martabak': 13, 'Minuman': 14, 'Pizza & pasta': 15, 'Roti': 16, 'Sate': 17, 'Seafood': 18, 'Sweets': 19, 'Timur Tengah': 20}

# %%
df_jakarta_coor = df_temp
print(f"Unique categories: {cat_to_code}")
df_jakarta_coor.head()
# Out:
# Unique categories: {'Aneka nasi': 1, 'Ayam & bebek': 2, 'Bakmie': 3, 'Bakso & soto': 4, 'Barat': 5, 'Cepat saji': 6, 'Chinese': 7, 'India': 8, 'Jajanan': 9, 'Jepang': 10, 'Kopi': 11, 'Korea': 12, 'Martabak': 13, 'Minuman': 14, 'Pizza & pasta': 15, 'Roti': 16, 'Sate': 17, 'Seafood': 18, 'Sweets': 19, 'Timur Tengah': 20}
#            merchant_name      category  \
# 0      330 Kopi, Ciledug  [11, 14, 16]
# 1     Abe Steak, Cibubur    [1, 14, 5]
# 2  Abuba Steak, Cikarang           [5]
# 3   Aneka Gorengan Siaga       [9, 14]
# 4            Arangsimpur           [7]
#
#                                                price  target_price  \
# 0  [20.0, 22.0, 20.0, 20.0, 22.0, 22.0, 15.0, 18....         20.00
# 1  [70.0, 33.0, 105.0, 100.0, 90.0, 165.0, 20.0, ...         18.00
# 2  [13.2, 35.2, 35.2, 49.5, 39.6, 44.0, 28.6, 28....         28.60
# 3  [1.5, 1.5, 1.5, 1.5, 1.5, 1.5, 2.0, 1.5, 1.5, ...          5.00
# 4                [34.0, 39.0, 48.0, 48.0, 6.0, 29.0]         30.25
#
#   price_category  price_min  price_max                          alamat  \
# 0              0       15.0       37.0      330 Kopi, Ciledug, Jakarta
# 1              1        5.0      165.0     Abe Steak, Cibubur, Jakarta
# 2              0       13.2      352.0  Abuba Steak, Cikarang, Jakarta
# 3              1        1.5       20.0   Aneka Gorengan Siaga, Jakarta
# 4              3        6.0       48.0            Arangsimpur, Jakarta
#
#         lat         lng                                               link
# 0 -6.238135  106.716900  https://www.google.com/maps/search/?api=1&quer...
# 1 -6.356087  106.879792  https://www.google.com/maps/search/?api=1&quer...
# 2 -6.194449  106.822920  https://www.google.com/maps/search/?api=1&quer...
# 3 -6.274045  106.839772  https://www.google.com/maps/search/?api=1&quer...
# 4 -6.240159  106.651125  https://www.google.com/maps/search/?api=1&quer...

# %% [markdown]
# ### Temp
